# %%
import os
import csv

datclinfile = "../../../data_clinical.csv"
pamresults = "./pamresults.txt"
hclustresults = "./hclustresults.csv"
with open(datclinfile,'r') as f:
        it = csv.reader(f)
        listit = list(it)
with open(hclustresults,'r') as f:
        it = csv.reader(f)
        datclust = list(it)

answers = {}
pams = {}
hclusts = {}

for x in range(7,len(listit)-1):
    if(listit[x][7] == "CIMP.H"):
        answers[listit[x][0]] = 1
    if(listit[x][7] == "CIMP.L"):
        answers[listit[x][0]] = 2
    if(listit[x][7] == "Cluster3"):
        answers[listit[x][0]] = 3
    if(listit[x][7] == "Cluster4"):
        answers[listit[x][0]] = 4
answers
# Out:
# {'TCGA-A6-2672': 1,
#  'TCGA-A6-2674': 4,
#  'TCGA-A6-2676': 1,
#  'TCGA-A6-2677': 3,
#  'TCGA-A6-2678': 3,
#  'TCGA-A6-2683': 2,
#  'TCGA-A6-3807': 4,
#  'TCGA-A6-3808': 3,
#  'TCGA-A6-3809': 1,
#  'TCGA-A6-3810': 4,
#  'TCGA-AA-3514': 3,
#  'TCGA-AA-3516': 1,
#  'TCGA-AA-3517': 4,
#  'TCGA-AA-3518': 1,
#  'TCGA-AA-3519': 3,
#  'TCGA-AA-3520': 3,
#  'TCGA-AA-3521': 3,
#  'TCGA-AA-3522': 2,
#  'TCGA-AA-3524': 4,
#  'TCGA-AA-3525': 1,
#  'TCGA-AA-3526': 3,
#  'TCGA-AA-3527': 2,
#  'TCGA-AA-3529': 4,
#  'TCGA-AA-3530': 4,
#  'TCGA-AA-3531': 4,
#  'TCGA-AA-3532': 4,
#  'TCGA-AA-3534': 3,
#  'TCGA-AA-3538': 4,
#  'TCGA-AA-3542': 4,
#  'TCGA-AA-3543': 1,
#  'TCGA-AA-3544': 3,
#  'TCGA-AA-3548': 3,
#  'TCGA-AA-3549': 2,
#  'TCGA-AA-3552': 3,
#  'TCGA-AA-3553': 4,
#  'TCGA-AA-3554': 4,
#  'TCGA-AA-3555': 2,
#  'TCGA-AA-3556': 2,
#  'TCGA-AA-3558': 2,
#  'TCGA-AA-3560': 3,
#  'TCGA-AA-3561': 3,
#  'TCGA-AA-3562': 3,
#  'TCGA-AA-3664': 1,
#  'TCGA-AA-3666': 4,
#  'TCGA-AA-3667': 4,
# ...

# %%
for row in datclust:
    hclusts[row[0]] = row[1]
for(key,value) in hclusts
# Out:
# {('TCGA.A6.2670', '1'): 1,
#  ('TCGA.A6.2672', '2'): 1,
#  ('TCGA.A6.2674', '3'): 1,
#  ('TCGA.A6.2676', '2'): 1,
#  ('TCGA.A6.2677', '3'): 1,
#  ('TCGA.A6.2678', '3'): 1,
#  ('TCGA.A6.2683', '3'): 1,
#  ('TCGA.A6.3807', '3'): 1,
#  ('TCGA.A6.3808', '1'): 1,
#  ('TCGA.A6.3809', '2'): 1,
#  ('TCGA.A6.3810', '4'): 1,
#  ('TCGA.AA.3514', '3'): 1,
#  ('TCGA.AA.3516', '2'): 1,
#  ('TCGA.AA.3517', '4'): 1,
#  ('TCGA.AA.3518', '2'): 1,
#  ('TCGA.AA.3519', '1'): 1,
#  ('TCGA.AA.3520', '3'): 1,
#  ('TCGA.AA.3521', '4'): 1,
#  ('TCGA.AA.3522', '1'): 1,
#  ('TCGA.AA.3524', '4'): 1,
#  ('TCGA.AA.3525', '2'): 1,
#  ('TCGA.AA.3526', '1'): 1,
#  ('TCGA.AA.3527', '3'): 1,
#  ('TCGA.AA.3529', '4'): 1,
#  ('TCGA.AA.3530', '4'): 1,
#  ('TCGA.AA.3531', '4'): 1,
#  ('TCGA.AA.3532', '4'): 1,
#  ('TCGA.AA.3534', '3'): 1,
#  ('TCGA.AA.3538', '4'): 1,
#  ('TCGA.AA.3542', '4'): 1,
#  ('TCGA.AA.3543', '2'): 1,
#  ('TCGA.AA.3544', '4'): 1,
#  ('TCGA.AA.3548', '3'): 1,
#  ('TCGA.AA.3549', '1'): 1,
# ...
