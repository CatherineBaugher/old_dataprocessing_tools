# %%
library(ggplot2)

a=c(1,1,1,1,1)
b=c(1,1,1,1,1)
df = data.frame(x=a,y=b)
ggplot(df, aes(x, y)) + geom_jitter()

# %%
a=c(1,1,1,1,1)
b=c(1,1,1,1,1)
df = data.frame(x=a,y=b)

# %%
ggplot(df, aes(x, y)) + geom_jitter()
# Out:
# plot without title

# %%
ggplot(df, aes(x, y)) + geom_jitter(width=0.01,height=0.01)
# Out:
# plot without title
